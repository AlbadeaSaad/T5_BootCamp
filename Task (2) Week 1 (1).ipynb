# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline 

df = pd.read_csv('Task (2) Dataset.csv')

# %%
df
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        62772.000000    62772.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922           10.588384       11.966725
# min               0.000000           49.381346       46.723235
# ...

# %%
correlation_matrix = df.select_dtypes(exclude = 'object').corr()
sb.heatmap(correlation_matrix, annot = True);

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.groupby('City').count()
# Out:
#           Datetime  TrafficIndexLive  JamsCount  JamsDelay  JamsLength  \
# City
# Abudhabi      3864              3864       3864       3864        3864
# Al-ain        3864              3864       3864       3864        3864
# Cairo         8690              8690       8690       8690        8690
# Dammam        3864              3864       3864       3864        3864
# Doha          8692              8692       8692       8692        8692
# Dubai         8690              8690       8690       8690        8690
# Jeddah        3864              3864       3864       3864        3864
# Kuwait        8691              8691       8691       8691        8691
# Mecca         3864              3864       3864       3864        3864
# Medina        3864              3864       3864       3864        3864
# Riyadh        8692              8692       8692       8692        8692
#
#           TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# City
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sb.histplot(df['TrafficIndexWeekAgo']);
sb.histplot(df['TravelTimeLive']);
sb.histplot(df['TravelTimeHistoric']);

# %%
sb.scatterplot(data = df, x = 'JamsCount', y = 'JamsLength', hue = 'City');

# %%
df_v = df.groupby('City')['JamsDelay'].mean()

# %%
df_v
# Out:
# City
# Abudhabi    107.800285
# Al-ain       22.606573
# Cairo       269.112911
# Dammam      123.072516
# Doha        127.612057
# Dubai       717.264856
# Jeddah      182.129322
# Kuwait      247.578610
# Mecca        42.870885
# Medina       36.790761
# Riyadh      620.349390
# Name: JamsDelay, dtype: float64

# %%
sb.barplot(x = df_v.values, y = df['City'].unique());

# %%
sb.scatterplot(data = df, x = 'TrafficIndexLive', y = 'JamsDelay', hue = 'City');

# %%
plt.figure(figsize=(10,6))
sb.barplot(data = df, x = 'City', y = 'JamsCount');

# %%
plt.figure(figsize=(10,6))
sb.barplot(data = df, x = 'City', y = 'TrafficIndexLive');

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
#
# - Data shows that Dubai and Riyadh has the highest record of Traffic, while Mecca and Medina are the lowest among all records
# - Aveage delay (waiting time) during traffic in Dubai and Riyadh is the highest among all record with more than 600minutes, while Mecca and Madina remains the lowest whith an average of 40 mins.
# - - There are a highly-positive correlation between jams count and jams length, whenever one increases, the other does too.
